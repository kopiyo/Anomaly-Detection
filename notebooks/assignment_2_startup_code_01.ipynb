# %% [markdown]
# <a href="https://colab.research.google.com/github/kopiyo/Anomaly-Detection/blob/master/notebooks/assignment_2_startup_code_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine Learning Assignment (2) Notebook (Startup Code)
#
# This notebook contains two tasks:
#
# ## Task 1: Gradient Descent for Second-Degree Polynomial Regression
# ## Task 2: Classification with Logistic Regression and Random Forest
#
# Complete both sections below.

# %% [markdown]
# =====================================================
#
# TASK 1: Polynomial Regression using Gradient Descent
# =====================================================
#
# You will:
# - Derive gradients manually
# - Implement gradient descent
# - Analyze convergence behavior

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load Dataset

# %%
url = "https://raw.githubusercontent.com/mdkamrulhasan/data-public/main/miscellaneous/second_degree_polynomial_regression_data.csv"
data = pd.read_csv(url)
data.head()
# Out:
#           x          y
# 0  1.478539 -10.538550
# 1 -0.814065  -2.124750
# 2 -0.121143  -1.992647
# 3  1.102154  -8.285820
# 4  1.562379 -11.587399

# %% [markdown]
# ## Prepare Data
#
# 🔹 Extract x and y as NumPy arrays.

# %%
# TODO
x = data.iloc[:, 0].values  # first column as feature
y = data.iloc[:, 1].values  # second column as target
n = len(x)
print("Number of samples:", n)
# Out:
# Number of samples: 100

# %% [markdown]
# ## Initialize Parameters

# %%
beta_0 = 0.0
beta_1 = 0.0
beta_2 = 1.0

learning_rate = 0.0001

print("Initial Parameters:")
print(beta_0, beta_1, beta_2)
# Out:
# Initial Parameters:
# 0.0 0.0 1.0

# %%
def predict(x, b0, b1, b2):
    return b0 + b1 * x + b2 * x**2

# %% [markdown]
# ## Loss Function

# %%
def compute_loss(x, y, b0, b1, b2):
    y_hat = predict(x, b0, b1, b2)

    # TODO

initial_loss = compute_loss(x, y, beta_0, beta_1, beta_2)
print("Initial Loss =", initial_loss)

# %% [markdown]
# ## Gradient Derivation

# %%
def compute_gradients(x, y, b0, b1, b2):
    # TODO (estimate model error)

    # Update Gradients
    d_b0 = None
    d_b1 = None
    d_b2 = None
    return d_b0, d_b1, d_b2

# %% [markdown]
# ## Gradient Descent Loop

# %%
iterations = 3
loss_history = []

for i in range(iterations):
    # TODO
    pass

# %% [markdown]
# ## Analysis & Reporting

# %%
# TODO

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# =====================================================
#
# TASK 2: Logistic Regression and Random Forest
# =====================================================

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

RANDOM_STATE = 42

# %% [markdown]
# ## Load Classification Dataset

# %%
url = "https://raw.githubusercontent.com/mdkamrulhasan/data-public/main/miscellaneous/adult_income_binary_processed.csv"
data = pd.read_csv(url)
data.head()

# %% [markdown]
# ## Train-Test Split

# %%
# TODO
X = None
y = None
X_train, X_test, y_train, y_test = None

# %% [markdown]
# ## Feature Encoding and Scaling

# %%
# TODO

# %% [markdown]
# ## Logistic Regression GridSearch

# %%
param_grid_logreg = {
    'logreg__C': [0.01, 0.1, 1, 10]
}

grid_logreg = GridSearchCV(LogisticRegression(), param_grid_logreg, cv=5, scoring='f1')
grid_logreg.fit(X_train, y_train)

# %% [markdown]
# ## Random Forest GridSearch

# %%
# TODO
# Complete this part by analyzing how it id done for Logistic Regression

# %% [markdown]
# ## Final Evaluation (On the TestSet)

# %%
# TODO

# %% [markdown]
# ## Analysis & Reporting

# %%
# TODO
